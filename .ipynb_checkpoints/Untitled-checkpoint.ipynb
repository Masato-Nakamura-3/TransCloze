# %%
import os

# %%
#new_list_batch1 = os.listdir("/Users/masato/Downloads/PW_2022.6.18-23/wav")
new_list_batch1 = os.listdir("/Users/masato/Library/CloudStorage/Box-Box/cloze_experiments/planet_cloze/batch0628/wav")

# %%
old_list_role = os.listdir("/Users/masato/Library/CloudStorage/Box-Box/cloze_experiments/planet_cloze/batch0625/wav_role")
old_list_reg = os.listdir("/Users/masato/Library/CloudStorage/Box-Box/cloze_experiments/planet_cloze/batch0625/wav_regular")

# %%
[n for n in old_list_role if ".webm" in n]
# Out:
# []

# %%
[n for n in new_list_batch1 if ".webm" in n]
# Out:
# []

# %%
(set(old_list_role) | set(old_list_reg)) & set(new_list_batch1)
# Out:
# set()

# %%
set(old_list_role) - set(new_list_batch1)
# Out:
# {'role_10a_nuxo.wav',
#  'role_10a_riby.wav',
#  'role_10a_uddn.wav',
#  'role_10b_deap.wav',
#  'role_10b_jcsc.wav',
#  'role_10b_uecq.wav',
#  'role_10b_ukou.wav',
#  'role_11a_birb.wav',
#  'role_11a_bpxx.wav',
#  'role_11a_chif.wav',
#  'role_11a_dqay.wav',
#  'role_11a_ecqd.wav',
#  'role_11a_ednc.wav',
#  'role_11a_ehsy.wav',
#  'role_11a_fwfs.wav',
#  'role_11a_hnhi.wav',
#  'role_11a_hrap.wav',
#  'role_11a_ipfv.wav',
#  'role_11a_kirs.wav',
#  'role_11a_kqgw.wav',
#  'role_11a_kxpe.wav',
#  'role_11a_oiqe.wav',
#  'role_11a_riht.wav',
#  'role_11a_sghw.wav',
#  'role_11a_syyq.wav',
#  'role_11a_tvef.wav',
#  'role_11a_uall.wav',
#  'role_11a_uygh.wav',
#  'role_11a_uznt.wav',
#  'role_11a_vuvv.wav',
#  'role_11a_ydic.wav',
#  'role_11a_zfjy.wav',
#  'role_11a_zppi.wav',
#  'role_11b_avds.wav',
#  'role_11b_cetk.wav',
#  'role_11b_dleb.wav',
#  'role_11b_dnyq.wav',
#  'role_11b_eena.wav',
#  'role_11b_fqfx.wav',
#  'role_11b_ftvq.wav',
#  'role_11b_ikgz.wav',
# ...

# %%
set(old_list_reg) - set(new_list_batch1)
# Out:
# {'regular_21c_deap.wav',
#  'regular_21c_jcsc.wav',
#  'regular_21c_uecq.wav',
#  'regular_21c_ukou.wav',
#  'regular_22c_birb.wav',
#  'regular_22c_bpxx.wav',
#  'regular_22c_chif.wav',
#  'regular_22c_dkcj.wav',
#  'regular_22c_dqay.wav',
#  'regular_22c_ecqd.wav',
#  'regular_22c_ednc.wav',
#  'regular_22c_ehsy.wav',
#  'regular_22c_fwfs.wav',
#  'regular_22c_hnhi.wav',
#  'regular_22c_hrap.wav',
#  'regular_22c_ipfv.wav',
#  'regular_22c_kirs.wav',
#  'regular_22c_kqgw.wav',
#  'regular_22c_kxpe.wav',
#  'regular_22c_nsvz.wav',
#  'regular_22c_oiqe.wav',
#  'regular_22c_riht.wav',
#  'regular_22c_sghw.wav',
#  'regular_22c_syyq.wav',
#  'regular_22c_tvef.wav',
#  'regular_22c_uall.wav',
#  'regular_22c_uygh.wav',
#  'regular_22c_uznt.wav',
#  'regular_22c_vuvv.wav',
#  'regular_22c_ydic.wav',
#  'regular_22c_zfjy.wav',
#  'regular_22c_zppi.wav',
#  'regular_23c_avds.wav',
#  'regular_23c_cetk.wav',
#  'regular_23c_dleb.wav',
#  'regular_23c_dnyq.wav',
#  'regular_23c_eena.wav',
# ...

# %%
set(new_list_batch1) - set(old_list_reg) - set(old_list_role)
# Out:
# set()
