# %%
import TransCloze
import pickle

# %%
cred = "/Users/masato/Documents/Research/transcription/googlecloud/autotranscription-test-e12d3589a265.json"

# %%
wav_dir = "/Users/masato/Library/CloudStorage/Box-Box/cloze_experiments/planet_cloze/batch0625/webm+wav"
ch_input = "/Users/masato/Library/CloudStorage/Box-Box/cloze_experiments/planet_cloze/batch0625/chronset_input"
ch_output = "/Users/masato/Library/CloudStorage/Box-Box/cloze_experiments/planet_cloze/batch0625/chronset_output"

#role_wav_dir = "/Users/masato/Library/CloudStorage/Box-Box/cloze_experiments/planet_cloze/batch0625/wav_role"
#regular_wav_dir = "/Users/masato/Library/CloudStorage/Box-Box/cloze_experiments/planet_cloze/batch0625/wav_regular"

# %%
tg_dir_role = "/Users/masato/Library/CloudStorage/Box-Box/cloze_experiments/planet_cloze/batch0625/tg_raw_role"

# %%
keyword0617= pickle.load( open( "/Users/masato/Library/CloudStorage/Box-Box/cloze_experiments/planet_cloze/keywords/keywords_0617_role.p", "rb" ) )

# %%
TransCloze.chronset_prep("pc0625", wav_dir, ch_input)
# Out:
# Created 3 zip files for 1156 wav files.

# %%
dict_transcription_0625 = TransCloze.transcribe(role_wav_dir, cred, prefix = ["role"], keyword = keyword0617)
# Out:
# role_1a_jcsc.wav:	B
# role_18a_ymum.wav:	Ram
# role_20b_dqay.wav:	like
# role_12a_dnyq.wav:	caught
# role_13b_lrbu.wav:	grew up
# role_15b_tvui.wav:	Thief caught
# Error at  role_19b_pufn.wav
# Error at  role_12b_ednc.wav
# Error at  role_13a_nsvz.wav
# role_8b_jcsc.wav:	it was written by
# Error at  role_11b_ymum.wav
# Error at  role_17b_whpp.wav
# role_20a_mgue.wav:	Drew
# role_18b_bpxx.wav:	ate
# role_14b_uygh.wav:	is running from
# role_15a_birb.wav:	found
# Error at  role_11a_bpxx.wav
# role_15a_zppi.wav:	policeman was chasing
# Error at  role_14b_vuvv.wav
# Error at  role_19b_fqfx.wav
# role_14a_avds.wav:	ate
# role_17a_riht.wav:	loved
# role_14b_tvef.wav:	scared of
# role_19b_ftvq.wav:	fooled
# role_19a_ehsy.wav:	disqualified
# role_8a_riby.wav:	what what
# role_12b_kirs.wav:	the app run away
# Error at  role_12b_uznt.wav
# Error at  role_17b_ikgz.wav
# Error at  role_1b_riby.wav
# role_2b_uecq.wav:	stop whenever you want
# role_14b_ipfv.wav:	woman escaped
# ...

# %%
pickle.dump(dict_transcription_0625, open( "/Users/masato/Library/CloudStorage/Box-Box/cloze_experiments/planet_cloze/batch0625/transcription_0617_role.p", "wb" ) )

# %%
onset_dict_0625 = TransCloze.chronset_dict(ch_output)

# %%
pickle.dump(onset_dict_0625, open( "/Users/masato/Library/CloudStorage/Box-Box/cloze_experiments/planet_cloze/batch0625/onset_0625_role.p", "wb" ) )

# %%
role= pickle.load( open( "/Users/masato/Library/CloudStorage/Box-Box/cloze_experiments/planet_cloze/contexts/context_role.p", "rb" ) )
onset= pickle.load( open( "/Users/masato/Library/CloudStorage/Box-Box/cloze_experiments/planet_cloze/batch0625/onset_0625_role.p", "rb" ) )
transc = pickle.load( open( "/Users/masato/Library/CloudStorage/Box-Box/cloze_experiments/planet_cloze/batch0625/transcription_0617_role.p", "rb" ) )

# %%
TransCloze.generate_textgrid(transc, tg_dir_role, wav_dir, prefix = ["role"], onset = onset, context = role, inconsistent = True)
# Out:
# No onset for  role_14b_vuvv
# No onset for  role_14a_rvje
# No onset for  role_20a_ymum
# No onset for  role_7b_riby
# No onset for  role_12a_avds
# No onset for  role_6a_nuxo
# No onset for  role_10a_nuxo
# No onset for  role_18a_iyom
# No onset for  role_15b_ftvq
# No onset for  role_11a_ipfv
# No onset for  role_11b_avds
# No onset for  role_13b_yptv
# No onset for  role_17b_rvje
# No onset for  role_17a_ipfv
# No onset for  role_11a_ednc
# No onset for  role_18b_chif
# No onset for  role_11a_syyq
# No onset for  role_18b_syyq
# No onset for  role_14b_ehsy
# No onset for  role_4a_nuxo
# No onset for  role_19b_keau
# No onset for  role_19b_rvje
# No onset for  role_18b_fwfs
# No onset for  role_20b_zppi
# No onset for  role_19b_phin
# No onset for  role_13b_rvje
# No onset for  role_12a_whtr
# No onset for  role_13a_vuvv
# No onset for  role_20b_ehsy
# No onset for  role_19a_dqay
# No onset for  role_12a_lrbu
# No onset for  role_8a_nuxo
# No onset for  role_11a_ehsy

# %%
#TransCloze.chronset_prep("pc1", "/Users/masato/Library/CloudStorage/Box-Box/cloze_experiments/PlanetCloze_wavfiles_combined", "/Users/masato/Library/CloudStorage/Box-Box/cloze_experiments/planet_cloze_transcription/chronset_input")

# %%
dict_transcription = TransCloze.transcribe(wav_dir, cred, prefix = ["regular", "role"])
# Out:
# role_1a_aeqd.wav:	frightened
# Error at  role_8b_srbh.wav
# role_3b_jksy.wav:	watched
# regular_53d_opaw.wav:	cup
# role_5a_ccaq.wav:	groomed
# regular_36c_jarp.wav:	surprise
# role_8b_dass.wav:	text
# role_2a_bpbo.wav:	saved
# Error at  role_9b_xign.wav
# regular_44d_phkv.wav:	joke
# regular_25c_ngfs.wav:	grow
# regular_56d_gyvk.wav:	game
# regular_28c_avtd.wav:	the park
# role_1a_yefl.wav:	Stone
# role_12b_ejwy.wav:	tilt
# role_4a_iemv.wav:	despised
# regular_57d_bkua.wav:	fridge
# regular_53d_kyxx.wav:	fruit
# role_6b_egzy.wav:	the hero that the dragonfly
# role_5a_yypk.wav:	washed
# role_1a_dass.wav:	stung
# Error at  role_8b_yefl.wav
# regular_29c_rjvv.wav:	soap
# Error at  role_1a_srbh.wav
# role_8b_aeqd.wav:	Road
# regular_32c_fixa.wav:	poop
# regular_27c_uqyl.wav:	door
# role_15a_dkvi.wav:	caught
# regular_37c_ohra.wav:	bench
# Error at  role_6b_hegy.wav
# role_3a_phkv.wav:	killed
# regular_25c_amvo.wav:	bro get food
# regular_40c_qbwr.wav:	head
# role_10b_ntcz.wav:	4  no
# ...

# %%
import pickle

# %%
pickle.dump(dict_transcription, open( "/Users/masato/Library/CloudStorage/Box-Box/cloze_experiments/planet_cloze/batch0617/transcription_0617.p", "wb" ) )

# %%
import importlib
importlib.reload(TransCloze)
# Out:
# <module 'TransCloze' from '/Users/masato/Documents/Research/transcription_module/TransCloze.py'>

# %%
onset_dict = TransCloze.chronset_dict(ch_output_dir)

# %%
pickle.dump(onset_dict, open( "/Users/masato/Library/CloudStorage/Box-Box/cloze_experiments/planet_cloze/batch0617/onset_0617.p", "wb" ) )

# %%
generate_textgrid(dict_transcription, "/Users/masato/Documents/Research/transcription_module/test_data/tg", onset = onset_dict, inconsistent = 1)
# Out:
# No onset for  role_8b_srbh
# No onset for  role_1a_srbh
# No onset for  regular_52d_dass
# No onset for  role_13b_ydbf
# No onset for  role_12a_ixvz
# No onset for  regular_40c_xign
# No onset for  role_2b_syzc
# No onset for  regular_60d_damf
# No onset for  role_7b_poad
# No onset for  role_1b_gyvk
# No onset for  regular_32c_fcvb
# No onset for  regular_60d_rljh
# No onset for  role_5b_nwfh
# No onset for  regular_36c_yefl
# No onset for  role_3b_tcaw
# No onset for  role_8b_jarp
# No onset for  role_9b_urch
# No onset for  regular_21c_hbvq
# No onset for  regular_24c_guhn
# No onset for  regular_24c_hway
# No onset for  role_6a_qqno
# No onset for  role_14a_tnfv
# No onset for  regular_21c_weih
# No onset for  role_9b_bnvv
# No onset for  role_8b_kcxh
# No onset for  regular_48d_bkua
# No onset for  regular_24c_fyms
# No onset for  role_4b_npwr
# No onset for  regular_40c_fyms
# No onset for  regular_32c_txlz
# No onset for  regular_57d_nkkr
# No onset for  role_10b_otxz
# ...

# %%
TransCloze.generate_textgrid(dict_transcription, tg_dir, wav_dir,onset = onset_dict, inconsistent = 1)
# Out:
# No onset for  role_8b_srbh
# No onset for  role_1a_srbh
# No onset for  regular_52d_dass
# No onset for  role_13b_ydbf
# No onset for  role_12a_ixvz
# No onset for  regular_40c_xign
# No onset for  role_2b_syzc
# No onset for  regular_60d_damf
# No onset for  role_7b_poad
# No onset for  role_1b_gyvk
# No onset for  regular_32c_fcvb
# No onset for  regular_60d_rljh
# No onset for  role_5b_nwfh
# No onset for  regular_36c_yefl
# No onset for  role_3b_tcaw
# No onset for  role_8b_jarp
# No onset for  role_9b_urch
# No onset for  regular_21c_hbvq
# No onset for  regular_24c_guhn
# No onset for  regular_24c_hway
# No onset for  role_6a_qqno
# No onset for  role_14a_tnfv
# No onset for  regular_21c_weih
# No onset for  role_9b_bnvv
# No onset for  role_8b_kcxh
# No onset for  regular_48d_bkua
# No onset for  regular_24c_fyms
# No onset for  role_4b_npwr
# No onset for  regular_40c_fyms
# No onset for  regular_32c_txlz
# No onset for  regular_57d_nkkr
# No onset for  role_10b_otxz
# ...

# %%
import pickle
reg= pickle.load( open( "/Users/masato/Library/CloudStorage/Box-Box/cloze_experiments/planet_cloze/contexts/context_regular.p", "rb" ) )
role= pickle.load( open( "/Users/masato/Library/CloudStorage/Box-Box/cloze_experiments/planet_cloze/contexts/context_role.p", "rb" ) )
onset= pickle.load( open( "/Users/masato/Library/CloudStorage/Box-Box/cloze_experiments/planet_cloze/batch0617/onset_0617.p", "rb" ) )
transc = pickle.load( open( "/Users/masato/Library/CloudStorage/Box-Box/cloze_experiments/planet_cloze/batch0617/transcription_0617.p", "rb" ) )

# %%
output_dir = "/Users/masato/Library/CloudStorage/Box-Box/cloze_experiments/planet_cloze/batch0617/tg_raw_regular"
wav_dir = "/Users/masato/Library/CloudStorage/Box-Box/cloze_experiments/planet_cloze/batch0617/temp"

# %%
TransCloze.generate_textgrid(transc, output_dir, wav_dir, onset = onset, context = reg, inconsistent = 1)
# Out:
# No onset for  regular_52d_dass
# No onset for  regular_40c_xign
# No onset for  regular_60d_damf
# No onset for  regular_32c_fcvb
# No onset for  regular_60d_rljh
# No onset for  regular_36c_yefl
# No onset for  regular_21c_hbvq
# No onset for  regular_24c_guhn
# No onset for  regular_24c_hway
# No onset for  regular_21c_weih
# No onset for  regular_48d_bkua
# No onset for  regular_24c_fyms
# No onset for  regular_40c_fyms
# No onset for  regular_32c_txlz
# No onset for  regular_57d_nkkr
# No onset for  regular_24c_urch
# No onset for  regular_41d_fyms
# No onset for  regular_41d_guhn
# No onset for  regular_60d_npwr
# No onset for  regular_52d_rljh
# No onset for  regular_49d_hway
# No onset for  regular_47d_aaez
# No onset for  regular_58d_tnfv
# No onset for  regular_57d_ngfs
# No onset for  regular_54d_qpdv
# No onset for  regular_24c_nkkr
# No onset for  regular_58d_ixvz
# No onset for  regular_32c_tcaw
# No onset for  regular_24c_dxvp
# No onset for  regular_52d_fmtd
# ...

# %%
onset["role_2a_gnky"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-0161cfc5a2b3> in <module>
# ----> 1 onset["role_2a_gnky"]
#
# KeyError: 'role_2a_gnky'

# %% [markdown]
# ### Keywords

# %%
keyword_0617 = TransCloze.get_keywords(tg_dir, combine_conditions = True)

# %%
pickle.dump(keyword_0617, open( "/Users/masato/Library/CloudStorage/Box-Box/cloze_experiments/planet_cloze/keywords/keywords_0617_role.p", "wb" ) )
